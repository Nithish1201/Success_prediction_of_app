# %% [markdown]
# # **Cleaning Data**

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in f:\nordic internship\projects\dsbjun21\lib\site-packages (0.1.20)
# Requirement already satisfied: click in f:\nordic internship\projects\dsbjun21\lib\site-packages (from opendatasets) (8.0.1)
# Requirement already satisfied: kaggle in f:\nordic internship\projects\dsbjun21\lib\site-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: tqdm in f:\nordic internship\projects\dsbjun21\lib\site-packages (from opendatasets) (4.62.2)
# Requirement already satisfied: colorama in f:\nordic internship\projects\dsbjun21\lib\site-packages (from click->opendatasets) (0.4.4)
# Requirement already satisfied: certifi in f:\nordic internship\projects\dsbjun21\lib\site-packages (from kaggle->opendatasets) (2021.5.30)
# Requirement already satisfied: python-slugify in f:\nordic internship\projects\dsbjun21\lib\site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: python-dateutil in f:\nordic internship\projects\dsbjun21\lib\site-packages (from kaggle->opendatasets) (2.8.1)
# Requirement already satisfied: urllib3 in f:\nordic internship\projects\dsbjun21\lib\site-packages (from kaggle->opendatasets) (1.26.6)
# Requirement already satisfied: requests in f:\nordic internship\projects\dsbjun21\lib\site-packages (from kaggle->opendatasets) (2.26.0)
# Requirement already satisfied: six>=1.10 in f:\nordic internship\projects\dsbjun21\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in f:\nordic internship\projects\dsbjun21\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in f:\nordic internship\projects\dsbjun21\lib\site-packages (from requests->kaggle->opendatasets) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in f:\nordic internship\projects\dsbjun21\lib\site-packages (from requests->kaggle->opendatasets) (2.0.4)
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'f:\nordic internship\projects\dsbjun21\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/gauthamp10/google-playstore-apps")
# Out:
# Skipping, found downloaded files in ".\google-playstore-apps" (use force=True to force download)

# %%
# !dir
# Out:
#  Volume in drive F is New Volume
#  Volume Serial Number is 6A7D-E31B
#
#  Directory of F:\nordic Internship\projects\Success_prediction_of_app
#
# 13-09-2021  08:39 PM    <DIR>          .
# 13-09-2021  08:39 PM    <DIR>          ..
# 12-09-2021  12:05 PM                45 .gitignore
# 13-09-2021  07:55 PM    <DIR>          .ipynb_checkpoints
# 13-09-2021  08:39 PM           722,927 EDA.ipynb
# 13-09-2021  09:41 AM    <DIR>          EDA_krish
# 12-09-2021  11:43 AM    <DIR>          google-playstore-apps
# 12-09-2021  11:41 AM                67 kaggle.json
# 12-09-2021  03:57 PM        61,865,079 Playstore-data.csv.gz
# 12-09-2021  05:15 PM           129,585 Playstore_cleaning.ipynb
# 09-09-2021  10:55 AM         1,368,085 Playstore_Preprocessing.ipynb
# 09-09-2021  09:44 AM                32 README.md
# 12-09-2021  01:46 PM               686 requirements.txt
#                8 File(s)     64,086,506 bytes
#                5 Dir(s)  36,437,364,736 bytes free

# %%
data = pd.read_csv('google-playstore-apps/Google-Playstore.csv')

# %%
data.shape
# Out:
# (2312944, 24)

# %%
data.head(4)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# 2              50.0                58  True    0.0  ...
# 3              10.0                19  True    0.0  ...
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
#
# [4 rows x 24 columns]

# %%
data['Category'].value_counts()
# Out:
# Education                  241090
# Music & Audio              154906
# Tools                      143988
# Business                   143771
# Entertainment              138276
# Lifestyle                  118331
# Books & Reference          116728
# Personalization             89210
# Health & Fitness            83510
# Productivity                79698
# Shopping                    75256
# Food & Drink                73927
# Travel & Local              67288
# Finance                     65466
# Arcade                      53792
# Puzzle                      51168
# Casual                      50813
# Communication               48167
# Sports                      47483
# Social                      44734
# News & Magazines            42807
# Photography                 35552
# Medical                     32065
# Action                      27555
# Maps & Navigation           26722
# Simulation                  23282
# Adventure                   23203
# Educational                 21308
# Art & Design                18539
# Auto & Vehicles             18280
# House & Home                14369
# Video Players & Editors     14015
# Events                      12841
# Trivia                      11795
# Beauty                      11772
# Board                       10588
# Racing                      10362
# Role Playing                10034
# Word                         8630
# Strategy                     8526
# Card                         8179
# Weather                      7246
# Dating                       6524
# Libraries & Demo             5198
# Casino                       5076
# Music                        4202
# Parenting                    3810
# Comics                       2862
# Name: Category, dtype: int64

# %%
len(data['Category'].value_counts())
# Out:
# 48

# %%
data['Currency'].value_counts()
# Out:
# USD    2311548
# XXX       1236
# EUR          6
# INR          5
# GBP          3
# CAD          2
# TRY          1
# RUB          1
# AUD          1
# BRL          1
# ZAR          1
# VND          1
# PKR          1
# SGD          1
# KRW          1
# Name: Currency, dtype: int64

# %%
data = data[data['Currency'] == 'USD']
data.drop(['Currency'],1,inplace=True)
data = data.reset_index(drop=True)

# %% [markdown]
# Taking the data which has **Currency** as **USD** and dropping the **Currency** column

# %%
data.shape
# Out:
# (2311548, 23)

# %% [markdown]
# ### Dropping unnecessory columns

# %%
data.drop(['App Name','App Id','Developer Website','Developer Email','Privacy Policy','Scraped Time','Installs','Editors Choice'],1,inplace=True)
data.head()
# Out:
#         Category  Rating  Rating Count  Minimum Installs  Maximum Installs  \
# 0      Adventure     0.0           0.0              10.0                15
# 1          Tools     4.4          64.0            5000.0              7662
# 2   Productivity     0.0           0.0              50.0                58
# 3  Communication     5.0           5.0              10.0                19
# 4          Tools     0.0           0.0             100.0               478
#
#    Free  Price  Size Minimum Android                       Developer Id  \
# 0  True    0.0   10M      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1  True    0.0  2.9M      5.0 and up                         Webserveis
# 2  True    0.0  3.7M    4.0.3 and up                         Cabin Crew
# 3  True    0.0  1.8M    4.0.3 and up                Climate Smart Tech2
# 4  True    0.0  6.2M      4.1 and up              Rafal Milek-Horodyski
#
#        Released  Last Updated Content Rating  Ad Supported  In App Purchases
# 0  Feb 26, 2020  Feb 26, 2020       Everyone         False             False
# 1  May 21, 2020  May 06, 2021       Everyone          True             False
# 2   Aug 9, 2019  Aug 19, 2019       Everyone         False             False
# 3  Sep 10, 2018  Oct 13, 2018       Everyone          True             False
# 4  Feb 21, 2020  Nov 12, 2018       Everyone         False             False

# %% [markdown]
# - Analyse **Catagory**
# - Change the data type of **Minimum Installs** and **Minimum Installs**
# - Combine **Rating** and **Rating Count** as **Sum of Ratings**
# - One hot encode the column **Free**
# - Remove **M** in **Size** column and make it as float64
# - Remove the text in **Minimum Android** and make it as float64 data type and rename it
# - Check data types of **Released** and **Last Updated**
# - Analyse the column **Content Rating**
# - One hot encode the columns --> **Ad Supported, In App Purchase, Editors**

# %%
data.columns
# Out:
# Index(['Category', 'Rating', 'Rating Count', 'Minimum Installs',
#        'Maximum Installs', 'Free', 'Price', 'Size', 'Minimum Android',
#        'Developer Id', 'Released', 'Last Updated', 'Content Rating',
#        'Ad Supported', 'In App Purchases'],
#       dtype='object')

# %%
data['Content Rating'].value_counts()
# Out:
# Everyone           2020913
# Teen                196224
# Mature 17+           60254
# Everyone 10+         33868
# Unrated                154
# Adults only 18+        135
# Name: Content Rating, dtype: int64

# %% [markdown]
# Can apply **One Hot Encoding**

# %%
print(data.shape)
data.dropna(subset=['Rating Count','Rating'],axis=0,inplace=True)
data.shape
# Out:
# (2311548, 15)
# (2288801, 15)

# %% [markdown]
# Dropping null values from **Rating Count and Rating** to create **Rating**

# %%
data['Rating Count'] = data['Rating Count'].astype(int)
data['Rating Sum'] = data['Rating Count'] * data['Rating']
data.head()
# Out:
#         Category  Rating  Rating Count  Minimum Installs  Maximum Installs  \
# 0      Adventure     0.0             0              10.0                15
# 1          Tools     4.4            64            5000.0              7662
# 2   Productivity     0.0             0              50.0                58
# 3  Communication     5.0             5              10.0                19
# 4          Tools     0.0             0             100.0               478
#
#    Free  Price  Size Minimum Android                       Developer Id  \
# 0  True    0.0   10M      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1  True    0.0  2.9M      5.0 and up                         Webserveis
# 2  True    0.0  3.7M    4.0.3 and up                         Cabin Crew
# 3  True    0.0  1.8M    4.0.3 and up                Climate Smart Tech2
# 4  True    0.0  6.2M      4.1 and up              Rafal Milek-Horodyski
#
#        Released  Last Updated Content Rating  Ad Supported  In App Purchases  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone         False             False
# 1  May 21, 2020  May 06, 2021       Everyone          True             False
# 2   Aug 9, 2019  Aug 19, 2019       Everyone         False             False
# 3  Sep 10, 2018  Oct 13, 2018       Everyone          True             False
# 4  Feb 21, 2020  Nov 12, 2018       Everyone         False             False
#
#    Rating Sum
# 0         0.0
# 1       281.6
# 2         0.0
# 3        25.0
# 4         0.0

# %%
data['Size'] = data['Size'].str.replace('M','')
data['Size'] = data['Size'].str.replace(',','')
data.drop(data[data['Size'] == 'Varies with device'].index, inplace = True)
data.drop(data[data['Size'].str.contains("k") == True].index, inplace = True)

# %% [markdown]
# Dropping Unnecessory rows with respect to **Size** and replacing string values to null to make it as **float** data type

# %%
index_lst_G = data[data['Size'].str.contains("G") == True].index.to_list()
print(len(index_lst_G))
# Out:
# 13

# %% [markdown]
# Checking for number of rows with GB sized apps.
# - As it is less for is affordable to covert them into MB sized data

# %%
for i in index_lst_G:
    data.loc[i,'Size'] = data.loc[i,'Size'].replace('G','')
    val = float(data.loc[i,'Size'])*1000
    data.loc[i,'Size'] = str(val)

# %%
data['Size'] = data['Size'].astype(float)

# %% [markdown]
# Converting the data type of **Size**

# %%
data['Minimum Android'] = data['Minimum Android'].str.replace(' and up','')
data['Minimum Android']
# Out:
# 0            7.1
# 1            5.0
# 2          4.0.3
# 3          4.0.3
# 4            4.1
#            ...
# 2311543      4.1
# 2311544      4.1
# 2311545      5.0
# 2311546      5.0
# 2311547      5.0
# Name: Minimum Android, Length: 2199515, dtype: object

# %% [markdown]
# Replacing Unnecessory Strings to empty String

# %%
data.loc[data['Minimum Android'].str.count('.') == 5.0,'Minimum Android'] = data[data['Minimum Android'].str.count('.') == 5.0]['Minimum Android'].str[:-2]

# %% [markdown]
# Trimming off the 3 Digit Versions to 2

# %%
data['Minimum Android'] = data['Minimum Android'].str.replace('W','')
print(data.shape)
data.drop(data[data['Minimum Android'] == 'Varies with device'].index, inplace = True)
data.shape
# Out:
# (2199515, 16)
# (2197783, 16)

# %% [markdown]
# Dropping and replacing of unwanted strings

# %%
data[data['Minimum Android'].str.count('.') > 5.0]['Minimum Android']
# Out:
# 2151       4.0.3 - 7.1.1
# 13638          4.4 - 6.0
# 18530          2.1 - 4.4
# 20993          4.0 - 5.0
# 24147        2.0 - 2.3.4
#                ...
# 2282236        4.0 - 6.0
# 2282337        2.3 - 4.4
# 2299017        4.0 - 6.0
# 2302402      4.0.3 - 6.0
# 2303669      4.0.3 - 6.0
# Name: Minimum Android, Length: 383, dtype: object

# %%
data.drop(data[data['Minimum Android'].str.count('.') > 5.0]['Minimum Android'].index, inplace = True)

# %% [markdown]
# As the number of rows which has complex versions are less, we **Drop** them

# %%
data
# Out:
#               Category  Rating  Rating Count  Minimum Installs  \
# 0            Adventure     0.0             0              10.0
# 1                Tools     4.4            64            5000.0
# 2         Productivity     0.0             0              50.0
# 3        Communication     5.0             5              10.0
# 4                Tools     0.0             0             100.0
# ...                ...     ...           ...               ...
# 2311543   Role Playing     4.3         16775          100000.0
# 2311544      Education     0.0             0             100.0
# 2311545      Education     0.0             0             100.0
# 2311546  Music & Audio     3.5             8            1000.0
# 2311547         Trivia     5.0            12             100.0
#
#          Maximum Installs  Free  Price  Size Minimum Android  \
# 0                      15  True    0.0  10.0             7.1
# 1                    7662  True    0.0   2.9             5.0
# 2                      58  True    0.0   3.7             4.0
# 3                      19  True    0.0   1.8             4.0
# 4                     478  True    0.0   6.2             4.1
# ...                   ...   ...    ...   ...             ...
# 2311543            337109  True    0.0  77.0             4.1
# 2311544               430  True    0.0  44.0             4.1
# 2311545               202  True    0.0  29.0             5.0
# 2311546              2635  True    0.0  10.0             5.0
# 2311547               354  True    0.0   5.2             5.0
#
#                               Developer Id      Released  Last Updated  \
# 0        Jean Confident Irénée NIYIZIBYOSE  Feb 26, 2020  Feb 26, 2020
# 1                               Webserveis  May 21, 2020  May 06, 2021
# 2                               Cabin Crew   Aug 9, 2019  Aug 19, 2019
# 3                      Climate Smart Tech2  Sep 10, 2018  Oct 13, 2018
# 4                    Rafal Milek-Horodyski  Feb 21, 2020  Nov 12, 2018
# ...                                    ...           ...           ...
# 2311543                         ALICE GAME           NaN  Jun 01, 2021
# 2311544                3Dream Studios, LLC  Jan 17, 2018  Feb 02, 2018
# 2311545                          appoworld  Aug 19, 2018  Aug 19, 2018
# 2311546                             Bhakti   Aug 1, 2016  May 05, 2021
# 2311547                          Y Yazılım   Aug 9, 2019  Aug 19, 2019
#
#         Content Rating  Ad Supported  In App Purchases  Rating Sum
# 0             Everyone         False             False         0.0
# 1             Everyone          True             False       281.6
# 2             Everyone         False             False         0.0
# 3             Everyone          True             False        25.0
# 4             Everyone         False             False         0.0
# ...                ...           ...               ...         ...
# 2311543           Teen         False             False     72132.5
# 2311544       Everyone         False             False         0.0
# 2311545       Everyone         False             False         0.0
# 2311546       Everyone          True             False        28.0
# 2311547       Everyone          True             False        60.0
#
# [2197400 rows x 16 columns]

# %%
data['Minimum Android'] = data['Minimum Android'].astype(float)

# %%
data['Minimum Installs'] = data['Minimum Installs'].astype(int)

# %%
data['Released'] = pd.to_datetime(data['Released'])
data['Last Updated'] = pd.to_datetime(data['Last Updated'])

# %% [markdown]
# Changing of data types

# %%
data.dtypes
# Out:
# Category                    object
# Rating                     float64
# Rating Count                 int32
# Minimum Installs             int32
# Maximum Installs             int64
# Free                          bool
# Price                      float64
# Size                       float64
# Minimum Android            float64
# Developer Id                object
# Released            datetime64[ns]
# Last Updated        datetime64[ns]
# Content Rating              object
# Ad Supported                  bool
# In App Purchases              bool
# Rating Sum                 float64
# dtype: object

# %%
data.head()
# Out:
#         Category  Rating  Rating Count  Minimum Installs  Maximum Installs  \
# 0      Adventure     0.0             0                10                15
# 1          Tools     4.4            64              5000              7662
# 2   Productivity     0.0             0                50                58
# 3  Communication     5.0             5                10                19
# 4          Tools     0.0             0               100               478
#
#    Free  Price  Size  Minimum Android                       Developer Id  \
# 0  True    0.0  10.0              7.1  Jean Confident Irénée NIYIZIBYOSE
# 1  True    0.0   2.9              5.0                         Webserveis
# 2  True    0.0   3.7              4.0                         Cabin Crew
# 3  True    0.0   1.8              4.0                Climate Smart Tech2
# 4  True    0.0   6.2              4.1              Rafal Milek-Horodyski
#
#     Released Last Updated Content Rating  Ad Supported  In App Purchases  \
# 0 2020-02-26   2020-02-26       Everyone         False             False
# 1 2020-05-21   2021-05-06       Everyone          True             False
# 2 2019-08-09   2019-08-19       Everyone         False             False
# 3 2018-09-10   2018-10-13       Everyone          True             False
# 4 2020-02-21   2018-11-12       Everyone         False             False
#
#    Rating Sum
# 0         0.0
# 1       281.6
# 2         0.0
# 3        25.0
# 4         0.0

# %%
data.isna().sum()
# Out:
# Category                0
# Rating                  0
# Rating Count            0
# Minimum Installs        0
# Maximum Installs        0
# Free                    0
# Price                   0
# Size                    0
# Minimum Android      6282
# Developer Id           30
# Released            45512
# Last Updated            0
# Content Rating          0
# Ad Supported            0
# In App Purchases        0
# Rating Sum              0
# dtype: int64

# %% [markdown]
# Finally checking and Dropping Null values

# %%
data.shape
# Out:
# (2197400, 16)

# %%
data.dropna(axis = 0, inplace = True)
data.shape
# Out:
# (2145742, 16)

# %%
for i in ["Category","Content Rating","Developer Id"]:
    print(data[data[i] == ''].index.to_list())
# Out:
# []
# []
# []

# %%
for i in ["Size","Minimum Android"]:
    print(data[data[i] == 0.0].index.to_list())
# Out:
# []
# []

# %% [markdown]
# Checking for **Hidden Null values**

# %%
data
# Out:
#               Category  Rating  Rating Count  Minimum Installs  \
# 0            Adventure     0.0             0                10
# 1                Tools     4.4            64              5000
# 2         Productivity     0.0             0                50
# 3        Communication     5.0             5                10
# 4                Tools     0.0             0               100
# ...                ...     ...           ...               ...
# 2311542      Education     3.4            17              1000
# 2311544      Education     0.0             0               100
# 2311545      Education     0.0             0               100
# 2311546  Music & Audio     3.5             8              1000
# 2311547         Trivia     5.0            12               100
#
#          Maximum Installs  Free  Price  Size  Minimum Android  \
# 0                      15  True    0.0  10.0              7.1
# 1                    7662  True    0.0   2.9              5.0
# 2                      58  True    0.0   3.7              4.0
# 3                      19  True    0.0   1.8              4.0
# 4                     478  True    0.0   6.2              4.1
# ...                   ...   ...    ...   ...              ...
# 2311542              1980  True    0.0  10.0              4.1
# 2311544               430  True    0.0  44.0              4.1
# 2311545               202  True    0.0  29.0              5.0
# 2311546              2635  True    0.0  10.0              5.0
# 2311547               354  True    0.0   5.2              5.0
#
#                               Developer Id   Released Last Updated  \
# 0        Jean Confident Irénée NIYIZIBYOSE 2020-02-26   2020-02-26
# 1                               Webserveis 2020-05-21   2021-05-06
# 2                               Cabin Crew 2019-08-09   2019-08-19
# 3                      Climate Smart Tech2 2018-09-10   2018-10-13
# 4                    Rafal Milek-Horodyski 2020-02-21   2018-11-12
# ...                                    ...        ...          ...
# 2311542                 Julio Augusto Vera 2018-05-22   2018-12-14
# 2311544                3Dream Studios, LLC 2018-01-17   2018-02-02
# 2311545                          appoworld 2018-08-19   2018-08-19
# 2311546                             Bhakti 2016-08-01   2021-05-05
# 2311547                          Y Yazılım 2019-08-09   2019-08-19
#
#         Content Rating  Ad Supported  In App Purchases  Rating Sum
# 0             Everyone         False             False         0.0
# 1             Everyone          True             False       281.6
# 2             Everyone         False             False         0.0
# 3             Everyone          True             False        25.0
# 4             Everyone         False             False         0.0
# ...                ...           ...               ...         ...
# 2311542       Everyone          True             False        57.8
# 2311544       Everyone         False             False         0.0
# 2311545       Everyone         False             False         0.0
# 2311546       Everyone          True             False        28.0
# 2311547       Everyone          True             False        60.0
#
# [2145742 rows x 16 columns]

# %%
data.rename(columns = {'Rating Count':'Rating_Count',
                       'Minimum Installs':'Min_Downloads',
                       'Maximum Installs':'Max_Downloads',
                       'Minimum Android':'Min_Version',
                       'Last Updated':'Last_Updated',
                       'Content Rating':'Content',
                       'Ad Supported':'Ad_Support',
                       'In App Purchases':'Inapp_Purchase',
                       'Rating Sum':'Rating_Sum',
                       'Developer Id':'DeveloperId'}, inplace = True)

# %%
from datetime import date
today = date.today()
today = pd.to_datetime(today)
today
# Out:
# Timestamp('2021-09-13 00:00:00')

# %%
data['Released_Before'] = ((today - data.Released)/np.timedelta64(1, 'M'))
data['Updated_Before'] = ((today - data.Last_Updated)/np.timedelta64(1, 'M'))
data['Released_Before'] = data['Released_Before'].astype(int)
data['Updated_Before'] = data['Updated_Before'].astype(int)

# %%
data
# Out:
#               Category  Rating  Rating_Count  Min_Downloads  Max_Downloads  \
# 0            Adventure     0.0             0             10             15
# 1                Tools     4.4            64           5000           7662
# 2         Productivity     0.0             0             50             58
# 3        Communication     5.0             5             10             19
# 4                Tools     0.0             0            100            478
# ...                ...     ...           ...            ...            ...
# 2311542      Education     3.4            17           1000           1980
# 2311544      Education     0.0             0            100            430
# 2311545      Education     0.0             0            100            202
# 2311546  Music & Audio     3.5             8           1000           2635
# 2311547         Trivia     5.0            12            100            354
#
#          Free  Price  Size  Min_Version                        DeveloperId  \
# 0        True    0.0  10.0          7.1  Jean Confident Irénée NIYIZIBYOSE
# 1        True    0.0   2.9          5.0                         Webserveis
# 2        True    0.0   3.7          4.0                         Cabin Crew
# 3        True    0.0   1.8          4.0                Climate Smart Tech2
# 4        True    0.0   6.2          4.1              Rafal Milek-Horodyski
# ...       ...    ...   ...          ...                                ...
# 2311542  True    0.0  10.0          4.1                 Julio Augusto Vera
# 2311544  True    0.0  44.0          4.1                3Dream Studios, LLC
# 2311545  True    0.0  29.0          5.0                          appoworld
# 2311546  True    0.0  10.0          5.0                             Bhakti
# 2311547  True    0.0   5.2          5.0                          Y Yazılım
#
#           Released Last_Updated   Content  Ad_Support  Inapp_Purchase  \
# 0       2020-02-26   2020-02-26  Everyone       False           False
# 1       2020-05-21   2021-05-06  Everyone        True           False
# 2       2019-08-09   2019-08-19  Everyone       False           False
# 3       2018-09-10   2018-10-13  Everyone        True           False
# 4       2020-02-21   2018-11-12  Everyone       False           False
# ...            ...          ...       ...         ...             ...
# 2311542 2018-05-22   2018-12-14  Everyone        True           False
# 2311544 2018-01-17   2018-02-02  Everyone       False           False
# 2311545 2018-08-19   2018-08-19  Everyone       False           False
# 2311546 2016-08-01   2021-05-05  Everyone        True           False
# 2311547 2019-08-09   2019-08-19  Everyone        True           False
#
#          Rating_Sum  Released_Before  Updated_Before
# 0               0.0               18              18
# 1             281.6               15               4
# 2               0.0               25              24
# 3              25.0               36              35
# 4               0.0               18              34
# ...             ...              ...             ...
# 2311542        57.8               39              32
# 2311544         0.0               43              43
# 2311545         0.0               36              36
# 2311546        28.0               61               4
# 2311547        60.0               25              24
#
# [2145742 rows x 18 columns]

# %%
data.drop(['Released','Last_Updated'],1,inplace=True)
data
# Out:
#               Category  Rating  Rating_Count  Min_Downloads  Max_Downloads  \
# 0            Adventure     0.0             0             10             15
# 1                Tools     4.4            64           5000           7662
# 2         Productivity     0.0             0             50             58
# 3        Communication     5.0             5             10             19
# 4                Tools     0.0             0            100            478
# ...                ...     ...           ...            ...            ...
# 2311542      Education     3.4            17           1000           1980
# 2311544      Education     0.0             0            100            430
# 2311545      Education     0.0             0            100            202
# 2311546  Music & Audio     3.5             8           1000           2635
# 2311547         Trivia     5.0            12            100            354
#
#          Free  Price  Size  Min_Version                        DeveloperId  \
# 0        True    0.0  10.0          7.1  Jean Confident Irénée NIYIZIBYOSE
# 1        True    0.0   2.9          5.0                         Webserveis
# 2        True    0.0   3.7          4.0                         Cabin Crew
# 3        True    0.0   1.8          4.0                Climate Smart Tech2
# 4        True    0.0   6.2          4.1              Rafal Milek-Horodyski
# ...       ...    ...   ...          ...                                ...
# 2311542  True    0.0  10.0          4.1                 Julio Augusto Vera
# 2311544  True    0.0  44.0          4.1                3Dream Studios, LLC
# 2311545  True    0.0  29.0          5.0                          appoworld
# 2311546  True    0.0  10.0          5.0                             Bhakti
# 2311547  True    0.0   5.2          5.0                          Y Yazılım
#
#           Content  Ad_Support  Inapp_Purchase  Rating_Sum  Released_Before  \
# 0        Everyone       False           False         0.0               18
# 1        Everyone        True           False       281.6               15
# 2        Everyone       False           False         0.0               25
# 3        Everyone        True           False        25.0               36
# 4        Everyone       False           False         0.0               18
# ...           ...         ...             ...         ...              ...
# 2311542  Everyone        True           False        57.8               39
# 2311544  Everyone       False           False         0.0               43
# 2311545  Everyone       False           False         0.0               36
# 2311546  Everyone        True           False        28.0               61
# 2311547  Everyone        True           False        60.0               25
#
#          Updated_Before
# 0                    18
# 1                     4
# 2                    24
# 3                    35
# 4                    34
# ...                 ...
# 2311542              32
# 2311544              43
# 2311545              36
# 2311546               4
# 2311547              24
#
# [2145742 rows x 16 columns]

# %%
data = data[['Category', 'Free', 'Price',
       'Size', 'Min_Version', 'DeveloperId', 'Released_Before', 'Updated_Before',
       'Content', 'Ad_Support', 'Inapp_Purchase','Rating', 'Rating_Count', 'Rating_Sum' , 'Min_Downloads' ,'Max_Downloads']]
data
# Out:
#               Category  Free  Price  Size  Min_Version  \
# 0            Adventure  True    0.0  10.0          7.1
# 1                Tools  True    0.0   2.9          5.0
# 2         Productivity  True    0.0   3.7          4.0
# 3        Communication  True    0.0   1.8          4.0
# 4                Tools  True    0.0   6.2          4.1
# ...                ...   ...    ...   ...          ...
# 2311542      Education  True    0.0  10.0          4.1
# 2311544      Education  True    0.0  44.0          4.1
# 2311545      Education  True    0.0  29.0          5.0
# 2311546  Music & Audio  True    0.0  10.0          5.0
# 2311547         Trivia  True    0.0   5.2          5.0
#
#                                DeveloperId  Released_Before  Updated_Before  \
# 0        Jean Confident Irénée NIYIZIBYOSE               18              18
# 1                               Webserveis               15               4
# 2                               Cabin Crew               25              24
# 3                      Climate Smart Tech2               36              35
# 4                    Rafal Milek-Horodyski               18              34
# ...                                    ...              ...             ...
# 2311542                 Julio Augusto Vera               39              32
# 2311544                3Dream Studios, LLC               43              43
# 2311545                          appoworld               36              36
# 2311546                             Bhakti               61               4
# 2311547                          Y Yazılım               25              24
#
#           Content  Ad_Support  Inapp_Purchase  Rating  Rating_Count  \
# 0        Everyone       False           False     0.0             0
# 1        Everyone        True           False     4.4            64
# 2        Everyone       False           False     0.0             0
# 3        Everyone        True           False     5.0             5
# 4        Everyone       False           False     0.0             0
# ...           ...         ...             ...     ...           ...
# 2311542  Everyone        True           False     3.4            17
# 2311544  Everyone       False           False     0.0             0
# 2311545  Everyone       False           False     0.0             0
# 2311546  Everyone        True           False     3.5             8
# 2311547  Everyone        True           False     5.0            12
#
#          Rating_Sum  Min_Downloads  Max_Downloads
# 0               0.0             10             15
# 1             281.6           5000           7662
# 2               0.0             50             58
# 3              25.0             10             19
# 4               0.0            100            478
# ...             ...            ...            ...
# 2311542        57.8           1000           1980
# 2311544         0.0            100            430
# 2311545         0.0            100            202
# 2311546        28.0           1000           2635
# 2311547        60.0            100            354
#
# [2145742 rows x 16 columns]

# %%
data.columns
# Out:
# Index(['Category', 'Free', 'Price', 'Size', 'Min_Version', 'DeveloperId',
#        'Released_Before', 'Updated_Before', 'Content', 'Ad_Support',
#        'Inapp_Purchase', 'Rating', 'Rating_Count', 'Rating_Sum',
#        'Min_Downloads', 'Max_Downloads'],
#       dtype='object')

# %% [markdown]
# Renaming and Reordering **Column Names**

# %%
print(data[data['Rating'] == 0.0].shape)
df = data[data['Rating'] == 0.0]
df[df['Rating_Count'] == 0].shape
# Out:
# (1005064, 16)
# (1005064, 16)

# %% [markdown]
# Noticing that there is no difference in them, we can drop the rows which has *zeros* in ```Rating```, so that every rows which has *zeros* in ```Rating``` and ```Rating_Sum```

# %%
print(data.shape)
data.drop(data[data['Rating'] == 0.0].index,inplace=True)
data.reset_index(drop=True,inplace=True)
print(data.shape)
data
# Out:
# (2145742, 16)
# (1140678, 16)
# f:\nordic internship\projects\dsbjun21\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                  Category  Free  Price  Size  Min_Version  \
# 0                   Tools  True    0.0   2.9          5.0
# 1           Communication  True    0.0   1.8          4.0
# 2        Libraries & Demo  True    0.0   2.5          4.1
# 3               Lifestyle  True    0.0  16.0          5.0
# 4         Personalization  True    0.0   3.5          4.1
# ...                   ...   ...    ...   ...          ...
# 1140673            Action  True    0.0  37.0          4.0
# 1140674     Music & Audio  True    0.0   4.1          2.2
# 1140675         Education  True    0.0  10.0          4.1
# 1140676     Music & Audio  True    0.0  10.0          5.0
# 1140677            Trivia  True    0.0   5.2          5.0
#
#                                  DeveloperId  Released_Before  Updated_Before  \
# 0                                 Webserveis               15               4
# 1                        Climate Smart Tech2               36              35
# 2                       android developer779               23              23
# 3                                 Mozaix LLC               26              26
# 4        Free 2021 Themes for Emoji keyboard               23              11
# ...                                      ...              ...             ...
# 1140673                          Upopa Games               70              54
# 1140674                 Single Cell Software               81              81
# 1140675                   Julio Augusto Vera               39              32
# 1140676                               Bhakti               61               4
# 1140677                            Y Yazılım               25              24
#
#           Content  Ad_Support  Inapp_Purchase  Rating  Rating_Count  \
# 0        Everyone        True           False     4.4            64
# 1        Everyone        True           False     5.0             5
# 2        Everyone        True           False     4.5            12
# 3        Everyone       False           False     2.0            39
# 4        Everyone        True           False     4.7           820
# ...           ...         ...             ...     ...           ...
# 1140673      Teen        True            True     4.3        103466
# 1140674  Everyone       False           False     4.0           344
# 1140675  Everyone        True           False     3.4            17
# 1140676  Everyone        True           False     3.5             8
# 1140677  Everyone        True           False     5.0            12
#
#          Rating_Sum  Min_Downloads  Max_Downloads
# 0             281.6           5000           7662
# 1              25.0             10             19
# 2              54.0           1000           2567
# 3              78.0            500            702
# 4            3854.0          50000          62433
# ...             ...            ...            ...
# 1140673    444903.8        5000000        7274660
# 1140674      1376.0         500000         814548
# 1140675        57.8           1000           1980
# 1140676        28.0           1000           2635
# 1140677        60.0            100            354
#
# [1140678 rows x 16 columns]

# %% [markdown]
# #### Making a meaningful **feature** from ```Min_Downloads``` and ```Max_Downloads``` to make it continuous

# %%
data[data["Max_Downloads"] == 0].shape
# Out:
# (137, 16)

# %% [markdown]
# Checking for zeros in ```Max_downloads```

# %%
print(data.shape)
data.drop(data[data["Max_Downloads"] == 0].index,inplace=True)
data.reset_index(drop=True,inplace=True)
data.shape
# Out:
# (1140678, 16)
# f:\nordic internship\projects\dsbjun21\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (1140541, 16)

# %% [markdown]
# we drop them because it may cause *Non-definite* values when divide ```0``` with ```2```

# %%
data['Average_Downloads'] = data['Min_Downloads'] +((data['Max_Downloads'] - data['Min_Downloads'])/2)
data.drop(['Rating','Rating_Count','Min_Downloads','Max_Downloads','DeveloperId'],1,inplace=True)
# Out:
# <ipython-input-56-c382c13529d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Average_Downloads'] = data['Min_Downloads'] +((data['Max_Downloads'] - data['Min_Downloads'])/2)

# %%
data.reset_index(drop=True)
# Out:
#                  Category  Free  Price  Size  Min_Version  Released_Before  \
# 0                   Tools  True    0.0   2.9          5.0               15
# 1           Communication  True    0.0   1.8          4.0               36
# 2        Libraries & Demo  True    0.0   2.5          4.1               23
# 3               Lifestyle  True    0.0  16.0          5.0               26
# 4         Personalization  True    0.0   3.5          4.1               23
# ...                   ...   ...    ...   ...          ...              ...
# 1140536            Action  True    0.0  37.0          4.0               70
# 1140537     Music & Audio  True    0.0   4.1          2.2               81
# 1140538         Education  True    0.0  10.0          4.1               39
# 1140539     Music & Audio  True    0.0  10.0          5.0               61
# 1140540            Trivia  True    0.0   5.2          5.0               25
#
#          Updated_Before   Content  Ad_Support  Inapp_Purchase  Rating_Sum  \
# 0                     4  Everyone        True           False       281.6
# 1                    35  Everyone        True           False        25.0
# 2                    23  Everyone        True           False        54.0
# 3                    26  Everyone       False           False        78.0
# 4                    11  Everyone        True           False      3854.0
# ...                 ...       ...         ...             ...         ...
# 1140536              54      Teen        True            True    444903.8
# 1140537              81  Everyone       False           False      1376.0
# 1140538              32  Everyone        True           False        57.8
# 1140539               4  Everyone        True           False        28.0
# 1140540              24  Everyone        True           False        60.0
#
#          Average_Downloads
# 0                   6331.0
# 1                     14.5
# 2                   1783.5
# 3                    601.0
# 4                  56216.5
# ...                    ...
# 1140536          6137330.0
# 1140537           657274.0
# 1140538             1490.0
# 1140539             1817.5
# 1140540              227.0
#
# [1140541 rows x 12 columns]

# %% [markdown]
# #### making the newly created columns to **```integer```**

# %%
data["Rating_Sum"] = data['Rating_Sum'].apply(np.int64)
# Out:
# <ipython-input-58-bb6c459bc1df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Rating_Sum"] = data['Rating_Sum'].apply(np.int64)

# %%
data["Average_Downloads"] = data['Average_Downloads'].apply(np.int64)
data.head()
# Out:
# <ipython-input-59-4604fbaca5a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Average_Downloads"] = data['Average_Downloads'].apply(np.int64)
#            Category  Free  Price  Size  Min_Version  Released_Before  \
# 0             Tools  True    0.0   2.9          5.0               15
# 1     Communication  True    0.0   1.8          4.0               36
# 2  Libraries & Demo  True    0.0   2.5          4.1               23
# 3         Lifestyle  True    0.0  16.0          5.0               26
# 4   Personalization  True    0.0   3.5          4.1               23
#
#    Updated_Before   Content  Ad_Support  Inapp_Purchase  Rating_Sum  \
# 0               4  Everyone        True           False         281
# 1              35  Everyone        True           False          25
# 2              23  Everyone        True           False          54
# 3              26  Everyone       False           False          78
# 4              11  Everyone        True           False        3854
#
#    Average_Downloads
# 0               6331
# 1                 14
# 2               1783
# 3                601
# 4              56216

# %%
data.describe(include = [np.number])
# Out:
#               Price          Size   Min_Version  Released_Before  \
# count  1.140541e+06  1.140541e+06  1.140541e+06     1.140541e+06
# mean   8.626702e-02  2.075248e+01  4.302165e+00     4.134720e+01
# std    1.834865e+00  2.529151e+01  8.452421e-01     2.700780e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00     2.000000e+00
# 25%    0.000000e+00  5.300000e+00  4.100000e+00     1.900000e+01
# 50%    0.000000e+00  1.100000e+01  4.100000e+00     3.600000e+01
# 75%    0.000000e+00  2.700000e+01  4.400000e+00     5.800000e+01
# max    3.999900e+02  1.500000e+03  8.000000e+00     1.390000e+02
#
#        Updated_Before    Rating_Sum  Average_Downloads
# count    1.140541e+06  1.140541e+06       1.140541e+06
# mean     2.076865e+01  1.617989e+04       2.796702e+05
# std      1.893555e+01  5.331710e+05       6.358865e+06
# min      2.000000e+00  5.000000e+00       1.000000e+00
# 25%      6.000000e+00  4.700000e+01       1.117000e+03
# 50%      1.400000e+01  1.360000e+02       5.207000e+03
# 75%      2.900000e+01  6.590000e+02       2.070400e+04
# max      1.390000e+02  2.521144e+08       1.561553e+09

# %%
data.describe(include = ['O'])
# Out:
#          Category   Content
# count     1140541   1140541
# unique         48         6
# top     Education  Everyone
# freq       120686    984038

# %%
data.to_csv('Playstore-data.csv.gz',compression='gzip')
