# %%
import pandas as pd
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('Playstore-data1.csv.gz',compression='gzip')
data1
# Out:
#          Unnamed: 0       Category  Min_Downloads  Free  Min_Version  \
# 0                 0          Tools           5000  True          5.0
# 1                 1   Productivity             50  True          4.0
# 2                 2  Communication             10  True          4.0
# 3                 3          Tools            100  True          4.1
# 4                 4         Social             50  True          6.0
# ...             ...            ...            ...   ...          ...
# 1898101     1898101      Education              5  True          4.4
# 1898102     1898102      Education           1000  True          4.1
# 1898103     1898103      Education            100  True          4.1
# 1898104     1898104      Education            100  True          5.0
# 1898105     1898105          Music           1000  True          5.0
#
#           Content  Ad_Support  Inapp_Purchase     Price      Size  \
# 0        Everyone        True           False  0.296365  0.190055
# ...

# %%
data1.drop(['Unnamed: 0','Min_Downloads'],1,inplace=True)
data1.head()
# Out:
#         Category  Free  Min_Version   Content  Ad_Support  Inapp_Purchase  \
# 0          Tools  True          5.0  Everyone        True           False
# 1   Productivity  True          4.0  Everyone       False           False
# 2  Communication  True          4.0  Everyone        True           False
# 3          Tools  True          4.1  Everyone       False           False
# 4         Social  True          6.0      Teen       False            True
#
#       Price      Size  Released_Before  Updated_Before  Average_Downloads
# 0  0.296365  0.190055         0.390706        0.074858           0.567183
# 1  0.296365  0.233542         0.516485        0.551717           0.258475
# 2  0.296365  0.104922         0.619254        0.639270           0.171003
# 3  0.296365  0.325689         0.423901        0.631728           0.367168
# 4  0.296365  0.683427         0.586059        0.506348           0.274358

# %%
data1 = pd.get_dummies(data1)
data1
# Out:
#          Free  Min_Version  Ad_Support  Inapp_Purchase     Price      Size  \
# 0        True          5.0        True           False  0.296365  0.190055
# 1        True          4.0       False           False  0.296365  0.233542
# 2        True          4.0        True           False  0.296365  0.104922
# 3        True          4.1       False           False  0.296365  0.325689
# 4        True          6.0       False            True  0.296365  0.683427
# ...       ...          ...         ...             ...       ...       ...
# 1898101  True          4.4       False           False  0.296365  0.336849
# 1898102  True          4.1        True           False  0.296365  0.411020
# 1898103  True          4.1       False           False  0.296365  0.675493
# 1898104  True          5.0       False           False  0.296365  0.601075
# 1898105  True          5.0        True           False  0.296365  0.411020
#
# ...

# %%
y = data1[['Average_Downloads']]
y
# Out:
#          Average_Downloads
# 0                 0.567183
# 1                 0.258475
# 2                 0.171003
# 3                 0.367168
# 4                 0.274358
# ...                    ...
# 1898101           0.116101
# 1898102           0.473443
# 1898103           0.361551
# 1898104           0.325106
# 1898105           0.486299
#
# [1898106 rows x 1 columns]

# %%
X = data1.drop(['Average_Downloads'],axis=1)
X
# Out:
#          Free  Min_Version  Ad_Support  Inapp_Purchase     Price      Size  \
# 0        True          5.0        True           False  0.296365  0.190055
# 1        True          4.0       False           False  0.296365  0.233542
# 2        True          4.0        True           False  0.296365  0.104922
# 3        True          4.1       False           False  0.296365  0.325689
# 4        True          6.0       False            True  0.296365  0.683427
# ...       ...          ...         ...             ...       ...       ...
# 1898101  True          4.4       False           False  0.296365  0.336849
# 1898102  True          4.1        True           False  0.296365  0.411020
# 1898103  True          4.1       False           False  0.296365  0.675493
# 1898104  True          5.0       False           False  0.296365  0.601075
# 1898105  True          5.0        True           False  0.296365  0.411020
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (1518484, 36) (379622, 36) (1518484, 1) (379622, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train, y_train)
yhat = linear_reg_model.predict(X_test)
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.131

# %%
from sklearn.tree import DecisionTreeRegressor
decision_model = DecisionTreeRegressor()  
decision_model.fit(X_train, y_train) 
predicted_decision_trees = decision_model.predict(X_test)
print ("Mean Absolute Error using Decision Tress : %.3f" % mean_absolute_error(y_test, predicted_decision_trees))
# Out:
# Mean Absolute Error using Decision Tress : 0.146

# %%
from sklearn.ensemble import RandomForestRegressor
forest_model = RandomForestRegressor(n_estimators=100, max_depth=10)
forest_model.fit(X_train, y_train )
predicted_random_forest = forest_model.predict(X_test)
print("Mean Absolute Error using Random Forest: %.3f" % mean_absolute_error(y_test, predicted_random_forest))
# Out:
# <ipython-input-20-dbe473ed9267>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest_model.fit(X_train, y_train )
# Mean Absolute Error using Random Forest: 0.126

# %%
from xgboost import XGBRegressor
xg_model = XGBRegressor(n_estimators=100)
xg_model.fit(X_train, y_train)
predicted_XGBoost = xg_model.predict(X_test)
print("Mean Absolute Error using XGBoost: %.3f" % mean_absolute_error(y_test, predicted_XGBoost))
# Out:
# Mean Absolute Error using XGBoost: 0.120

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_error
SGD_model =SGDRegressor(max_iter = 1000,penalty = "elasticnet",loss = 'huber',tol = 1e-3, average = True)
SGD_model.fit(X_train, y_train)
predicted_SGD = SGD_model.predict(X_test)
print("Mean Absolute Error using SGD: %.3f" % mean_absolute_error(y_test, predicted_SGD))
# Out:
# f:\nordic internship\projects\dsbjun21\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Mean Absolute Error using SGD: 0.133

# %%
from sklearn.linear_model import ElasticNet
elasticNet_model = ElasticNet(alpha=1.0, l1_ratio=0.5)
elasticNet_model.fit(X_train, y_train)
predicted_elasticNet = elasticNet_model.predict(X_test)
print("Mean Absolute Error using Elastic net: %.3f" % mean_absolute_error(y_test, predicted_elasticNet))
# Out:
# Mean Absolute Error using Elastic net: 0.159

# %%
from sklearn.ensemble import GradientBoostingRegressor
GDboost_model = GradientBoostingRegressor()
GDboost_model.fit(X_train, y_train)
predicted_GDboost = GDboost_model.predict(X_test)
print("Mean Absolute Error using GD boost: %.3f" % mean_absolute_error(y_test, predicted_GDboost))
# Out:
# f:\nordic internship\projects\dsbjun21\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Mean Absolute Error using GD boost: 0.128
